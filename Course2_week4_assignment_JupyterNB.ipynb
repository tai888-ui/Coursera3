# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio via GitHub-link

# %% [markdown]
# ## Tai Lim

# %% [markdown]
# <i>I am interested in Data Science because I strongly believe that innovation or an abilty to think 'out-of-the-box' can challenge the status quo. This is applicable to finance as well in the healthcare sector.</i>

# %% [markdown]
# ### Show my first graph

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0,10,100)
plt.rcParams.update({'font.size':15})
ax = plt.axes()
plt.plot(x, np.sin(x), color='green', label='sin(x)')
plt.axis([0,10, -1,1])
plt.title ('My first graph')
plt.legend(loc='lower left')
ax.set(xlabel='x', ylabel = 'sin(x)')
# Out:
# [Text(0, 0.5, 'sin(x)'), Text(0.5, 0, 'x')]
